# %% [markdown]
# # K-Means Clustering

# %% [markdown]
# ## create sample data
# First, let's generate a 2D dataset containing four distinct blobs. To emphasize that this is an
# unsupervised approach, we will leave the labels out of the visualization. We will continue
# using Matplotlib for all our visualization purposes:

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_blobs

rng = np.random.RandomState(0)
colors = rng.rand(300)

#we will create a total of 300 blobs(n_samples=300) belonging to four distinct clusters (centers=4):
X, y_true = make_blobs(n_samples=300, centers=4,
                       cluster_std=0.85, random_state=2)

plt.style.use('seaborn-darkgrid')
plt.figure(figsize=(10,7))
plt.scatter(X[:, 0], X[:, 1], s=200, alpha=0.4, cmap='viridis')
plt.show()

# %% [markdown]
# Even without assigning target labels to the data, it is straightforward to pick out the four
# clusters by eye. The $k$-means algorithm can do this, too, without having any information
# about target labels or underlying data distributions.

# %% [markdown]
# ## create K-Means Model
# We use the same method "fit" to train our model.

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# # prediction
# Let's output the clustering results corresponding to the first 20 data.

# %%
y_kmeans = kmeans.predict(X)

# %%
print("output", y_kmeans[0:20])
# Out:
# output [2 2 0 2 3 1 2 1 0 2 3 2 2 1 1 3 0 1 3 2]

# %%
plt.figure(figsize=(10,7))

# plot group of data
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=250, alpha=0.5, cmap='viridis')
centers = kmeans.cluster_centers_

# plot cluster/centroid
plt.scatter(centers[0, 0], centers[0, 1], c='blue', s=300, alpha=0.7, label='centroid 1')
plt.scatter(centers[1, 0], centers[1, 1], c='black', s=300, alpha=0.7, label='centroid 2')
plt.scatter(centers[2, 0], centers[2, 1], c='red', s=300, alpha=0.7, label='centroid 3')
plt.scatter(centers[3, 0], centers[3, 1], c='gray', s=300, alpha=0.7, label='centroid 4')

plt.legend(frameon=True, loc='lower left')
plt.show()

# %% [markdown]
# We can see that there are four centroids.And now we can clearly see that the data is divided into four clusters.

# %% [markdown]
# # create new data points
# Let's create some new data points.

# %%
X_test, y_test_true = make_blobs(n_samples=10, centers=4, 
                                 cluster_std=0.85, random_state=2)

# %%
X_test.shape
# Out:
# (10, 2)

# %% [markdown]
# # Visualize new data points

# %%
plt.figure(figsize=(10,7))

# plot group of data
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=250, alpha=0.5, cmap='viridis')
centers = kmeans.cluster_centers_

# plot cluster/centroid
plt.scatter(centers[0, 0], centers[0, 1], c='blue', s=300, alpha=0.7, label='centroid 1')
plt.scatter(centers[1, 0], centers[1, 1], c='black', s=300, alpha=0.7, label='centroid 2')
plt.scatter(centers[2, 0], centers[2, 1], c='red', s=300, alpha=0.7, label='centroid 3')
plt.scatter(centers[3, 0], centers[3, 1], c='gray', s=300, alpha=0.7, label='centroid 4')

# plot new data point
plt.scatter(X_test[:, 0], X_test[:, 1], c='white', s=350, alpha=1, label='new data point')
plt.legend(frameon=True, loc='lower left')

plt.show()

# %% [markdown]
# Newly created data points are represented in white.

# %% [markdown]
# ## Predict new data points

# %%
y_test_kmeans = kmeans.predict(X_test)

# %%
y_test_kmeans
# Out:
# array([0, 3, 0, 3, 1, 1, 2, 3, 1, 2])

# %%
plt.figure(figsize=(10,7))

# plot group of data
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=250, alpha=0.5, cmap='viridis')
centers = kmeans.cluster_centers_

# plot cluster/centroid
#plt.scatter(centers[:, 0], centers[:, 1], c='blue', s=300, alpha=0.8, label='centroids')
plt.scatter(centers[0, 0], centers[0, 1], c='blue', s=300, alpha=0.7, label='centroid 1')
plt.scatter(centers[1, 0], centers[1, 1], c='black', s=300, alpha=0.7, label='centroid 2')
plt.scatter(centers[2, 0], centers[2, 1], c='red', s=300, alpha=0.7, label='centroid 3')
plt.scatter(centers[3, 0], centers[3, 1], c='gray', s=300, alpha=0.7, label='centroid 4')

# plot new data point
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test_kmeans, s=250, alpha=0.5, cmap='viridis')
plt.legend(frameon=True, loc='lower left')

plt.show()

# %% [markdown]
# Newly created data points are represented in white.
